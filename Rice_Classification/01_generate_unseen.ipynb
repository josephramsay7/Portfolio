# %%
import pandas as pd
import numpy as np
import joblib
from pycaret.classification import *

from sklearn.metrics import classification_report

# %%
data = pd.read_csv('./data/rice.csv')

# %%
unseen_data = data.sample(frac=.30, random_state=42)
df = data.drop(unseen_data.index)
df
# Out:
#        Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 1     14656  494.311005         206.020065          91.730972      0.895405
# 2     14634  501.122009         214.106781          87.768288      0.912118
# 3     13176  458.342987         193.337387          87.448395      0.891861
# 4     14688  507.166992         211.743378          89.312454      0.906691
# 5     13479  477.015991         200.053055          86.650291      0.901328
# ...     ...         ...                ...                ...           ...
# 3800  11611  431.273010         178.513947          84.112518      0.882036
# 3805  11441  415.858002         170.486771          85.756592      0.864280
# 3806  11625  421.390015         167.714798          89.462570      0.845850
# 3808   9882  392.296997         161.193985          78.210480      0.874406
# 3809  11434  404.709992         161.079269          90.868195      0.825692
#
#       Convex_Area    Extent     Class
# ...

# %%
# Does my row count match:
data.shape[0] == df.shape[0] + unseen_data.shape[0]
# Out:
# True

# %%
unseen_data.to_csv('./data/unseen_rice.csv', index=False)
df.to_csv('./data/rice_tt.csv', index=False)
